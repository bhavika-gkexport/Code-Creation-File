# %%
import pandas as pd

# %%
# make gemstone Item code from final_data.json file

df = pd.read_excel("Yellow.xlsx")
import json
codes = []
box = []
# Assuming the JSON data is stored in a file named "data.json"
with open('final_data 1.json', 'r') as file:
    data = json.load(file)
for i in df.values.tolist():
    print(i)
    code = 'G-' + data['gemstone_type'][i[0].lower()] + '-' + data['stone_shape'][i[1].lower()] + '-' + data['gemstone_quality'][i[2].lower()] + '-' + data['gemstone_grade'][i[3].lower()] + '-' + data['gemstone_size'][i[4].lower()] + '-' + data['cut_or_cab'][i[5].lower()] + '-' + str(data['gemstone_pr'][str(i[6]).split('.')[0]]) + '-' + data['per_pc_per_carat'][i[7].lower()]
    # print(code)
    codes.append(code)
    box.append(i[8])

df['Gemstone Code'] = codes
df['Box No'] = box
df.to_excel('Yellow Close.xlsx',index=False)
# Out:
# ['Blue Stone', 'Round', 'Synthetic', 'AD', '5.00 MM', 'Faceted', 60, 'Per Carat', 15]
# ['Blue Stone', 'Square', 'Synthetic', 'AD', '3.00*3.00 MM', 'Faceted', 60, 'Per Carat', 14]
# ['Blue Stone', 'Pear', 'Synthetic', 'AD', '9.00*7.00 MM', 'Faceted', 40, 'Per Carat', 14]
# ['Blue Stone', 'Pear', 'Synthetic', 'AD', '5.00*3.00 MM', 'Faceted', 80, 'Per Carat', 14]
# ['Firoza', 'Octagon', 'Semi-precious', 'Real Treated', '5.00*4.00 MM', 'Faceted', 60, 'Per Carat', 14]
# ['Blue Stone', 'Round', 'Synthetic', 'AD', '2.20 MM', 'Faceted', 20, 'Per Pc', 14]
# ['Blue Stone', 'Pear', 'Synthetic', 'AD', '6.00*4.00 MM', 'Faceted', 60, 'Per Carat', 14]
# ['Blue Stone', 'Pear', 'Synthetic', 'AD', '8.00*6.00 MM', 'Faceted', 40, 'Per Carat', 14]
# ['Green Stone', 'Round', 'Hydro', 'AD', '5.00 MM', 'Faceted', 20, 'Per Pc', 13]
# ['Green Stone', 'Round', 'Hydro', 'AD', '3.00 MM', 'Faceted', 15, 'Per Pc', 13]
# ['Green Stone', 'Round', 'Hydro', 'AD', '1.90 MM', 'Faceted', 15, 'Per Pc', 13]
# ['Green Stone', 'Round', 'Hydro', 'AD', '3.30 MM', 'Faceted', 15, 'Per Pc', 13]
# ['Green Stone', 'Round', 'Hydro', 'AD', '4.50 MM', 'Faceted', 20, 'Per Pc', 13]
# ['Green Stone', 'Round', 'Hydro', 'AD', '2.20 MM', 'Faceted', 15, 'Per Pc', 13]
# ['Green Stone', 'Round', 'Hydro', 'AD', '2.70 MM', 'Faceted', 15, 'Per Pc', 13]
# ['Green Stone', 'Round', 'Hydro', 'AD', '2.10 MM', 'Faceted', 15, 'Per Pc', 13]
# ['Green Stone', 'Round', 'Hydro', 'AD', '2.00 MM', 'Faceted', 15, 'Per Pc', 13]
# ['Green Stone', 'Round', 'Hydro', 'AD', '3.80 MM', 'Faceted', 15, 'Per Pc', 13]
# ['Green Stone', 'Round', 'Hydro', 'AD', '1.80 MM', 'Faceted', 15, 'Per Pc', 13]
# ['Green Stone', 'Round', 'Hydro', 'AD', '2.80 MM', 'Faceted', 15, 'Per Pc', 13]
# ['Green Stone', 'Round', 'Hydro', 'AD', '1.60 MM', 'Faceted', 15, 'Per Pc', 13]
# ['Green Stone', 'Round', 'Hydro', 'AD', '4.00 MM', 'Faceted', 20, 'Per Pc', 13]
# ['Green Stone', 'Round', 'Hydro', 'AD', '4.30 MM', 'Faceted', 20, 'Per Pc', 13]
# ['Green Stone', 'Round', 'Hydro', 'AD', '3.40 MM', 'Faceted', 15, 'Per Pc', 13]
# ['Green Stone', 'Round', 'Hydro', 'AD', '3.50 MM', 'Faceted', 15, 'Per Pc', 13]
# ['Green Stone', 'Round', 'Hydro', 'AD', '2.50 MM', 'Faceted', 15, 'Per Pc', 13]
# ['Green Stone', 'Round', 'Hydro', 'AD', '5.50 MM', 'Faceted', 20, 'Per Pc', 13]
# ['Green Stone', 'Octagon', 'Hydro', 'AD', '4.00*4.00 MM', 'Faceted', 85, 'Per Carat', 13]
# ['Green Stone', 'Baguette', 'Hydro', 'AD', '8.00*6.00 MM', 'Faceted', 85, 'Per Carat', 13]
# ['Green Stone', 'Baguette', 'Hydro', 'AD', '6.00*4.00 MM', 'Faceted', 85, 'Per Carat', 13]
# ['Green Stone', 'Square', 'Hydro', 'AD', '4.00*4.00 MM', 'Faceted', 85, 'Per Carat', 13]
# ['Green Stone', 'Baguette', 'Hydro', 'AD', '3.00*3.00 MM', 'Faceted', 85, 'Per Carat', 13]
# ['Green Stone', 'Baguette', 'Hydro', 'AD', '3.50*3.50 MM', 'Faceted', 120, 'Per Carat', 13]
# ['Green Stone', 'Oval', 'Hydro', 'AD', '10.00*8.00 MM', 'Faceted', 65, 'Per Carat', 12]
# ['Green Stone', 'Oval', 'Hydro', 'AD', '9.00*7.00 MM', 'Faceted', 65, 'Per Carat', 12]
# ['Green Stone', 'Oval', 'Hydro', 'AD', '6.00*4.00 MM', 'Faceted', 85, 'Per Carat', 12]
# ['Green Stone', 'Oval', 'Hydro', 'AD', '7.00*5.00 MM', 'Faceted', 65, 'Per Carat', 12]
# ['Green Stone', 'Oval', 'Hydro', 'AD', '5.50*4.50 MM', 'Faceted', 85, 'Per Carat', 12]
# ['Green Stone', 'Oval', 'Hydro', 'AD', '6.00*4.00 MM', 'Faceted', 85, 'Per Carat', 12]
# ['Green Stone', 'Oval', 'Hydro', 'AD', '11.00*8.00 MM', 'Faceted', 65, 'Per Carat', 12]
# ['Green Stone', 'Oval', 'Hydro', 'AD', '11.00*9.00 MM', 'Faceted', 65, 'Per Carat', 12]
# ['Green Stone', 'Oval', 'Hydro', 'AD', '5.00*3.00 MM', 'Faceted', 85, 'Per Carat', 12]
# ['Green Stone', 'Oval', 'Hydro', 'AD', '3.00*2.00 MM', 'Faceted', 120, 'Per Carat', 12]
# ['Green Stone', 'Oval', 'Hydro', 'AD', '4.00*3.00 MM', 'Faceted', 120, 'Per Carat', 12]
# ['Green Stone', 'Pear', 'Hydro', 'AD', '4.00*3.00 MM', 'Faceted', 120, 'Per Carat', 12]
# ['Green Stone', 'Pear', 'Hydro', 'AD', '5.50*4.50 MM', 'Faceted', 85, 'Per Carat', 12]
# ['Green Stone', 'Pear', 'Hydro', 'AD', '8.00*6.00 MM', 'Faceted', 65, 'Per Carat', 12]
# ['Green Stone', 'Pear', 'Hydro', 'AD', '10.00*8.00 MM', 'Faceted', 65, 'Per Carat', 12]
# ['Green Stone', 'Pear', 'Hydro', 'AD', '11.00*9.00 MM', 'Faceted', 65, 'Per Carat', 12]
# ['Green Stone', 'Pear', 'Hydro', 'AD', '12.00*9.00 MM', 'Faceted', 65, 'Per Carat', 12]
# ['Green Stone', 'Pear', 'Hydro', 'AD', '5.00*3.00 MM', 'Faceted', 85, 'Per Carat', 12]
# ['Green Stone', 'Pear', 'Hydro', 'AD', '3.00*2.00 MM', 'Faceted', 120, 'Per Carat', 12]
# ['Green Stone', 'Pear', 'Hydro', 'AD', '6.00*4.00 MM', 'Faceted', 85, 'Per Carat', 12]
# ['Green Stone', 'Pear', 'Hydro', 'AD', '3.50*2.50 MM', 'Faceted', 120, 'Per Carat', 12]
# ['Green Stone', 'Pear', 'Hydro', 'AD', '7.00*5.00 MM', 'Faceted', 65, 'Per Carat', 12]
# ['Green Stone', 'Pear', 'Hydro', 'AD', '12.00*10.00 MM', 'Faceted', 65, 'Per Carat', 12]
# ['Green Stone', 'Pear', 'Hydro', 'AD', '5.00*4.00 MM', 'Faceted', 85, 'Per Carat', 12]

# %%
D:\code creation\test.ipynb

# %%
df1 = pd.read_excel("Yellow Close.xlsx")
a = []
for i in df1.values.tolist():
    # print(i)
    gem_type = []
    stone_shape = []
    gemstone_quality = []
    gemstone_grade = []
    gemstone_size = []
    cut_or_cab = []
    gemstone_pr = []
    per_pc_per_carat = []



    gem_type.append("Gemstone Type")
    gem_type.append(i[0])
    gem_type.append("G")
    gem_type.append("Gemstone - V")
    gem_type.append("Carat")
    gem_type.append("G")
    gem_type.append("1")
    gem_type.append("1")
    gem_type.append(i[8])
    gem_type.append("KG GK Jewellers Private Limited")
    gem_type.append(i[9])

    # stone_shape.append(None)
    stone_shape.append("Stone Shape")
    stone_shape.append(i[1])
    stone_shape.append("G")

    # gemstone_quality.append(None)
    gemstone_quality.append("Gemstone Quality")
    gemstone_quality.append(i[2])
    gemstone_quality.append("G")
    
    # gemstone_grade.append(None)
    gemstone_grade.append("Gemstone Grade")
    gemstone_grade.append(i[3])
    gemstone_grade.append("G")

    # gemstone_size.append(None)
    gemstone_size.append("Gemstone Size")
    gemstone_size.append(i[4])
    gemstone_size.append("G")

    # cut_or_cab.append(None)
    cut_or_cab.append("Faceted/Cabochon")
    cut_or_cab.append(i[5])
    cut_or_cab.append("G")

    # gemstone_pr.append(None)
    gemstone_pr.append("Gemstone PR")
    gemstone_pr.append(i[6])
    gemstone_pr.append("G")

    # per_pc_per_carat.append(None)
    per_pc_per_carat.append("Per Pc or Per Carat")
    per_pc_per_carat.append(i[7])
    per_pc_per_carat.append("G")

    a.append(gem_type)
    a.append(stone_shape)
    a.append(gemstone_quality)
    a.append(gemstone_grade)
    a.append(gemstone_size)
    a.append(cut_or_cab)
    a.append(gemstone_pr)
    a.append(per_pc_per_carat)

# %%
d1 = pd.DataFrame(a,columns=['Attribute (Variant Attributes)','Attribute Value (Variant Attributes)','Variant Of (Variant Attributes)','Item Group','Default Unit of Measure','Variant Of','Maintain Stock','Include Item In Manufacturing','Box No','Company','Item Code'])

# %%
d1.to_excel("Yellow Close Ready For upload.xlsx",index=False)
